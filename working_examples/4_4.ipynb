# %%
import pandas as pd
country = pd.read_csv('../../data/PovStatsCountry.csv', na_values='', keep_default_na=False)
country['is_country'] = country['Region'].notna()
country[['Short Name', 'Region', 'is_country']].sample(10)
# Out:
#                                          Short Name  \
# 50         Fragile and conflict affected situations
# 147                              Sub-Saharan Africa
# 60                                       The Gambia
# 123                                     Netherlands
# 1                                            Angola
# 15                                          Belarus
# 3                                         Argentina
# 115                                      Mauritania
# 55                                            Gabon
# 37   IDA countries classified as fragile situations
#
#                         Region  is_country
# 50                         NaN       False
# 147                        NaN       False
# 60          Sub-Saharan Africa        True
# 123      Europe & Central Asia        True
# 1           Sub-Saharan Africa        True
# 15       Europe & Central Asia        True
# 3    Latin America & Caribbean        True
# 115         Sub-Saharan Africa        True
# 55          Sub-Saharan Africa        True
# 37                         NaN       False
