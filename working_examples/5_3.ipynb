# %%
import pandas as pd
poverty = pd.read_csv('../../data/poverty.csv', low_memory=False)
income_share_df =\
poverty.filter(regex='Country Name|^year$|Income share.*?20').dropna()
income_share_df
# Out:
#      Country Name  year  Income share held by fourth 20%  \
# 67        Albania  1996                             23.3
# 73        Albania  2002                             22.2
# 76        Albania  2005                             22.5
# 79        Albania  2008                             22.2
# 83        Albania  2012                             22.8
# ...           ...   ...                              ...
# 8229       Zambia  2006                             19.1
# 8233       Zambia  2010                             17.9
# 8238       Zambia  2015                             19.3
# 8279     Zimbabwe  2011                             21.0
# 8285     Zimbabwe  2017                             20.6
#
#       Income share held by highest 20%  Income share held by lowest 20%  \
# 67                                36.1                              9.2
# 73                                40.4                              8.4
# 76                                39.2                              8.4
# 79                                39.0                              8.9
# 83                                37.8                              8.9
# ...                                ...                              ...
# 8229                              59.5                              3.5
# 8233                              61.1                              3.8
# 8238                              61.3                              2.9
# 8279                              49.7                              5.8
# 8285                              51.1                              6.0
#
#       Income share held by second 20%  Income share held by third 20%
# 67                               13.7                            17.7
# 73                               12.6                            16.5
# 76                               12.9                            17.0
# 79                               13.1                            16.8
# 83                               13.2                            17.3
# ...                               ...                             ...
# 8229                              6.8                            11.1
# 8233                              6.8                            10.5
# 8238                              6.0                            10.6
# 8279                              9.5                            14.0
# 8285                              9.1                            13.2
#
# [1674 rows x 7 columns]
