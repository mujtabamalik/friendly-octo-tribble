# %%
import pandas as pd
data = pd.read_csv('../../data/PovStatsData.csv')
data = data.drop('Unnamed: 50', axis=1)
print(data.shape)
data.sample(3)
# Out:
# (11840, 50)
#      Country Name Country Code  \
# 1694      Belarus          BLR
# 5011       Guyana          GUY
# 5591      Ireland          IRL
#
#                                          Indicator Name  Indicator Code  1974  \
# 1694  Poverty gap at $5.50 a day (2011 PPP) (% of po...  SI.POV.UMIC.GP   NaN
# 5011  Multidimensional poverty, Educational enrollme...  SI.POV.ENRL.MI   NaN
# 5591  Multidimensional poverty, Sanitation (% of pop...  SI.POV.SANI.MI   NaN
#
#       1975  1976  1977  1978  1979  ...  2010  2011  2012  2013  2014  2015  \
# 1694   NaN   NaN   NaN   NaN   NaN  ...   0.6   0.4   0.2   0.1   0.1   0.1
# 5011   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5591   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#       2016  2017  2018  2019
# 1694   0.1   0.1   0.1   NaN
# 5011   NaN   NaN   NaN   NaN
# 5591   0.1   NaN   NaN   NaN
#
# [3 rows x 50 columns]
