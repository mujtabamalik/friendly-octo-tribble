# %%
import pandas as pd
data = pd.read_csv('../../data/PovStatsData.csv')
data = data.drop('Unnamed: 50', axis=1)
id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']
data_melt = pd.melt(data, id_vars=id_vars, var_name='year').dropna(subset=['value'])
data_melt['year'] = data_melt['year'].astype(int)
print(data_melt.shape)
data_melt.sample(10)
# Out:
# (44417, 6)
#          Country Name Country Code  \
# 523906       Colombia          COL
# 341980       Thailand          THA
# 436043          Spain          ESP
# 274525         Brazil          BRA
# 366446  United States          USA
# 409736     Mauritania          MRT
# 395020        Finland          FIN
# 514252       Honduras          HND
# 389025         Sweden          SWE
# 493781       Pakistan          PAK
#
#                                            Indicator Name  Indicator Code  \
# 523906  Annualized growth in per capita real survey me...  SI.SPR.PT60.ZG
# 341980          Poverty gap at $1.90 a day (2011 PPP) (%)     SI.POV.GAPS
# 436043                   Income share held by highest 20%  SI.DST.05TH.20
# 274525  Poverty gap at $3.20 a day (2011 PPP) (% of po...  SI.POV.LMIC.GP
# 366446  Poverty headcount ratio at $5.50 a day (2011 P...     SI.POV.UMIC
# 409736  Growth component of change in poverty at $5.50...  SI.POV.UMIC.GR
# 395020                    Income share held by lowest 10%  SI.DST.FRST.10
# 514252                    Income share held by lowest 10%  SI.DST.FRST.10
# 389025  Poverty headcount ratio at $1.90 a day (2011 P...     SI.POV.DDAY
# 493781  Multidimensional poverty, Headcount ratio (% o...  SI.POV.HCRT.MI
#
#         year  value
# 523906  2018   0.16
# 341980  2002   0.20
# 436043  2010  41.70
# 274525  1997  12.00
# 366446  2004   1.70
# 409736  2008  90.40
# 395020  2007   3.80
# 514252  2017   1.10
# 389025  2006   0.30
# 493781  2015  11.50
